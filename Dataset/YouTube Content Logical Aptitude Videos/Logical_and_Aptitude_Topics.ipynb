# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# !pip install beautifulsoup4 selenium
import bs4 # or from bs4 import BeautifulSoup
from selenium import webdriver
# !apt-get update
# !apt-get install -y chromium-chromedriver
# !pip install selenium
# !apt-get update
# !apt-get install -y wget unzip
# !wget https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb
# !dpkg -i google-chrome-stable_current_amd64.deb
# !apt-get -f install -y  # Fix broken dependencies
# !rm google-chrome-stable_current_amd64.deb

# Install latest ChromeDriver
# !wget -N https://chromedriver.storage.googleapis.com/$(wget -qO- https://chromedriver.storage.googleapis.com/LATEST_RELEASE)/chromedriver_linux64.zip
# !unzip chromedriver_linux64.zip
# !chmod +x chromedriver
# !mv chromedriver /usr/bin/chromedriver
# !rm /usr/bin/chromedriver
# !wget -N https://edgedl.me.gvt1.com/edgedl/chrome/chrome-for-testing/134.0.6998.88/linux64/chromedriver-linux64.zip
# !unzip chromedriver-linux64.zip
# !chmod +x chromedriver-linux64/chromedriver
# !mv chromedriver-linux64/chromedriver /usr/bin/chromedriver
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

chrome_options = Options()
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--disable-dev-shm-usage")
chrome_options.add_argument("--remote-debugging-port=9222")  # Enable remote debugging
chrome_options.add_argument("--disable-gpu")
chrome_options.add_argument("--disable-extensions")
chrome_options.add_argument("--headless")  # Remove this line if you want to see the browser


service = Service("/usr/bin/chromedriver")
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.13.3)
# Collecting selenium
#   Downloading selenium-4.31.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (4.13.1)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (2.3.0)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.29.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.11/dist-packages (from selenium) (2025.1.31)
# Requirement already satisfied: websocket-client~=1.8 in /usr/local/lib/python3.11/dist-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium) (25.3.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium) (3.10)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium) (1.3.1)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Downloading selenium-4.31.0-py3-none-any.whl (9.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 29.8 MB/s eta 0:00:00
# Downloading trio-0.29.0-py3-none-any.whl (492 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.9/492.9 kB 23.9 MB/s eta 0:00:00
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Installing collected packages: wsproto, outcome, trio, trio-websocket, selenium
# Successfully installed outcome-1.3.0.post0 selenium-4.31.0 trio-0.29.0 trio-websocket-0.12.2 wsproto-1.2.0
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,384 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,692 kB]
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Hit:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Get:13 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,788 kB]
# Get:14 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,832 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,140 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,243 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [4,246 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,542 kB]
# Fetched 26.1 MB in 4s (7,237 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   apparmor chromium-browser libfuse3-3 libudev1 snapd squashfs-tools
#   systemd-hwe-hwdb udev
# Suggested packages:
#   apparmor-profiles-extra apparmor-utils fuse3 zenity | kdialog
# The following NEW packages will be installed:
#   apparmor chromium-browser chromium-chromedriver libfuse3-3 snapd
#   squashfs-tools systemd-hwe-hwdb udev
# The following packages will be upgraded:
#   libudev1
# 1 upgraded, 8 newly installed, 0 to remove and 35 not upgraded.
# Need to get 30.3 MB of archives.
# After this operation, 123 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 apparmor amd64 3.0.4-2ubuntu2.4 [598 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 squashfs-tools amd64 1:4.5-3build1 [159 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libudev1 amd64 249.11-0ubuntu3.15 [76.6 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 udev amd64 249.11-0ubuntu3.15 [1,557 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfuse3-3 amd64 3.10.5-1build1 [81.2 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 snapd amd64 2.67.1+22.04 [27.8 MB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 chromium-browser amd64 1:85.0.4183.83-0ubuntu2.22.04.1 [49.2 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 chromium-chromedriver amd64 1:85.0.4183.83-0ubuntu2.22.04.1 [2,308 B]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 systemd-hwe-hwdb all 249.11.5 [3,228 B]
# Fetched 30.3 MB in 3s (11.6 MB/s)
# Preconfiguring packages ...
# Selecting previously unselected package apparmor.
# (Reading database ... 126332 files and directories currently installed.)
# Preparing to unpack .../apparmor_3.0.4-2ubuntu2.4_amd64.deb ...
# Unpacking apparmor (3.0.4-2ubuntu2.4) ...
# Selecting previously unselected package squashfs-tools.
# Preparing to unpack .../squashfs-tools_1%3a4.5-3build1_amd64.deb ...
# Unpacking squashfs-tools (1:4.5-3build1) ...
# Preparing to unpack .../libudev1_249.11-0ubuntu3.15_amd64.deb ...
# Unpacking libudev1:amd64 (249.11-0ubuntu3.15) over (249.11-0ubuntu3.12) ...
# Setting up libudev1:amd64 (249.11-0ubuntu3.15) ...
# Selecting previously unselected package udev.
# (Reading database ... 126532 files and directories currently installed.)
# Preparing to unpack .../udev_249.11-0ubuntu3.15_amd64.deb ...
# Unpacking udev (249.11-0ubuntu3.15) ...
# Selecting previously unselected package libfuse3-3:amd64.
# Preparing to unpack .../libfuse3-3_3.10.5-1build1_amd64.deb ...
# Unpacking libfuse3-3:amd64 (3.10.5-1build1) ...
# Selecting previously unselected package snapd.
# Preparing to unpack .../snapd_2.67.1+22.04_amd64.deb ...
# Unpacking snapd (2.67.1+22.04) ...
# Setting up apparmor (3.0.4-2ubuntu2.4) ...
# Created symlink /etc/systemd/system/sysinit.target.wants/apparmor.service → /lib/systemd/system/apparmor.service.
# Setting up squashfs-tools (1:4.5-3build1) ...
# Setting up udev (249.11-0ubuntu3.15) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up libfuse3-3:amd64 (3.10.5-1build1) ...
# Setting up snapd (2.67.1+22.04) ...
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.apparmor.service → /lib/systemd/system/snapd.apparmor.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.autoimport.service → /lib/systemd/system/snapd.autoimport.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.core-fixup.service → /lib/systemd/system/snapd.core-fixup.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.recovery-chooser-trigger.service → /lib/systemd/system/snapd.recovery-chooser-trigger.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.seeded.service → /lib/systemd/system/snapd.seeded.service.
# Created symlink /etc/systemd/system/cloud-final.service.wants/snapd.seeded.service → /lib/systemd/system/snapd.seeded.service.
# Unit /lib/systemd/system/snapd.seeded.service is added as a dependency to a non-existent unit cloud-final.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.service → /lib/systemd/system/snapd.service.
# Created symlink /etc/systemd/system/timers.target.wants/snapd.snap-repair.timer → /lib/systemd/system/snapd.snap-repair.timer.
# Created symlink /etc/systemd/system/sockets.target.wants/snapd.socket → /lib/systemd/system/snapd.socket.
# Created symlink /etc/systemd/system/final.target.wants/snapd.system-shutdown.service → /lib/systemd/system/snapd.system-shutdown.service.
# Selecting previously unselected package chromium-browser.
# (Reading database ... 126761 files and directories currently installed.)
# Preparing to unpack .../chromium-browser_1%3a85.0.4183.83-0ubuntu2.22.04.1_amd64.deb ...
# => Installing the chromium snap
# ==> Checking connectivity with the snap store
# ===> System doesn't have a working snapd, skipping
# Unpacking chromium-browser (1:85.0.4183.83-0ubuntu2.22.04.1) ...
# Selecting previously unselected package chromium-chromedriver.
# Preparing to unpack .../chromium-chromedriver_1%3a85.0.4183.83-0ubuntu2.22.04.1_amd64.deb ...
# Unpacking chromium-chromedriver (1:85.0.4183.83-0ubuntu2.22.04.1) ...
# Selecting previously unselected package systemd-hwe-hwdb.
# Preparing to unpack .../systemd-hwe-hwdb_249.11.5_all.deb ...
# Unpacking systemd-hwe-hwdb (249.11.5) ...
# Setting up systemd-hwe-hwdb (249.11.5) ...
# Setting up chromium-browser (1:85.0.4183.83-0ubuntu2.22.04.1) ...
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/x-www-browser (x-www-browser) in auto mode
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/gnome-www-browser (gnome-www-browser) in auto mode
# Setting up chromium-chromedriver (1:85.0.4183.83-0ubuntu2.22.04.1) ...
# Processing triggers for udev (249.11-0ubuntu3.15) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for dbus (1.12.20-2ubuntu4.1) ...
# Requirement already satisfied: selenium in /usr/local/lib/python3.11/dist-packages (4.31.0)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (2.3.0)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.11/dist-packages (from selenium) (0.29.0)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.11/dist-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.11/dist-packages (from selenium) (2025.1.31)
# Requirement already satisfied: typing_extensions~=4.9 in /usr/local/lib/python3.11/dist-packages (from selenium) (4.13.1)
# Requirement already satisfied: websocket-client~=1.8 in /usr/local/lib/python3.11/dist-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium) (25.3.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium) (3.10)
# Requirement already satisfied: outcome in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.11/dist-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# unzip is already the newest version (6.0-26ubuntu3.2).
# wget is already the newest version (1.21.2-2ubuntu1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# --2025-04-18 10:14:43--  https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb
# Resolving dl.google.com (dl.google.com)... 142.250.141.190, 142.250.141.93, 142.250.141.136, ...
# Connecting to dl.google.com (dl.google.com)|142.250.141.190|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 115256744 (110M) [application/x-debian-package]
# Saving to: ‘google-chrome-stable_current_amd64.deb’
#
# google-chrome-stabl 100%[===================>] 109.92M  27.5MB/s    in 4.8s
#
# 2025-04-18 10:14:48 (22.8 MB/s) - ‘google-chrome-stable_current_amd64.deb’ saved [115256744/115256744]
#
# Selecting previously unselected package google-chrome-stable.
# (Reading database ... 126789 files and directories currently installed.)
# Preparing to unpack google-chrome-stable_current_amd64.deb ...
# Unpacking google-chrome-stable (135.0.7049.95-1) ...
# dpkg: dependency problems prevent configuration of google-chrome-stable:
#  google-chrome-stable depends on libvulkan1; however:
#   Package libvulkan1 is not installed.
#
# dpkg: error processing package google-chrome-stable (--install):
#  dependency problems - leaving unconfigured
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Errors were encountered while processing:
#  google-chrome-stable
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Correcting dependencies... Done
# The following additional packages will be installed:
#   libvulkan1 mesa-vulkan-drivers
# The following NEW packages will be installed:
#   libvulkan1 mesa-vulkan-drivers
# 0 upgraded, 2 newly installed, 0 to remove and 35 not upgraded.
# 1 not fully installed or removed.
# Need to get 10.9 MB of archives.
# After this operation, 51.3 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvulkan1 amd64 1.3.204.1-2 [128 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 mesa-vulkan-drivers amd64 23.2.1-1ubuntu3.1~22.04.3 [10.7 MB]
# Fetched 10.9 MB in 1s (8,999 kB/s)
# Selecting previously unselected package libvulkan1:amd64.
# (Reading database ... 126906 files and directories currently installed.)
# Preparing to unpack .../libvulkan1_1.3.204.1-2_amd64.deb ...
# Unpacking libvulkan1:amd64 (1.3.204.1-2) ...
# Selecting previously unselected package mesa-vulkan-drivers:amd64.
# Preparing to unpack .../mesa-vulkan-drivers_23.2.1-1ubuntu3.1~22.04.3_amd64.deb ...
# Unpacking mesa-vulkan-drivers:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up libvulkan1:amd64 (1.3.204.1-2) ...
# Setting up mesa-vulkan-drivers:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up google-chrome-stable (135.0.7049.95-1) ...
# update-alternatives: using /usr/bin/google-chrome-stable to provide /usr/bin/x-www-browser (x-www-browser) in auto mode
# update-alternatives: using /usr/bin/google-chrome-stable to provide /usr/bin/gnome-www-browser (gnome-www-browser) in auto mode
# update-alternatives: using /usr/bin/google-chrome-stable to provide /usr/bin/google-chrome (google-chrome) in auto mode
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# --2025-04-18 10:15:14--  https://chromedriver.storage.googleapis.com/114.0.5735.90/chromedriver_linux64.zip
# Resolving chromedriver.storage.googleapis.com (chromedriver.storage.googleapis.com)... 142.250.101.207, 142.251.2.207, 142.250.141.207, ...
# Connecting to chromedriver.storage.googleapis.com (chromedriver.storage.googleapis.com)|142.250.101.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7407250 (7.1M) [application/zip]
# Saving to: ‘chromedriver_linux64.zip’
#
# chromedriver_linux6 100%[===================>]   7.06M  --.-KB/s    in 0.1s
#
# 2025-04-18 10:15:15 (61.3 MB/s) - ‘chromedriver_linux64.zip’ saved [7407250/7407250]
#
# Archive:  chromedriver_linux64.zip
#   inflating: chromedriver
#   inflating: LICENSE.chromedriver
# --2025-04-18 10:15:15--  https://edgedl.me.gvt1.com/edgedl/chrome/chrome-for-testing/134.0.6998.88/linux64/chromedriver-linux64.zip
# Resolving edgedl.me.gvt1.com (edgedl.me.gvt1.com)... 34.104.35.123, 2600:1900:4110:86f::
# Connecting to edgedl.me.gvt1.com (edgedl.me.gvt1.com)|34.104.35.123|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://storage.googleapis.com/chrome-for-testing-public/134.0.6998.88/linux64/chromedriver-linux64.zip [following]
# --2025-04-18 10:15:15--  https://storage.googleapis.com/chrome-for-testing-public/134.0.6998.88/linux64/chromedriver-linux64.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.251.2.207, 142.250.141.207, 74.125.137.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.251.2.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9521717 (9.1M) [application/zip]
# Saving to: ‘chromedriver-linux64.zip’
#
# chromedriver-linux6 100%[===================>]   9.08M  41.8MB/s    in 0.2s
#
# 2025-04-18 10:15:16 (41.8 MB/s) - ‘chromedriver-linux64.zip’ saved [9521717/9521717]
#
# Archive:  chromedriver-linux64.zip
#   inflating: chromedriver-linux64/LICENSE.chromedriver
#   inflating: chromedriver-linux64/THIRD_PARTY_NOTICES.chromedriver
#   inflating: chromedriver-linux64/chromedriver

# %%
topics = [
    # Logical Reasoning (1-30)
    "Alphanumeric series",
    "Reasoning Analogies",
    "Artificial Language",
    "Blood Relations",
    "Calendars",
    "Cause and Effect",
    "Clocks",
    "Coding-Decoding",
    "Critical path",
    "Cubes and cuboids",
    "Data Sufficiency",
    "Decision Making",
    "Deductive Reasoning/Statement Analysis",
    "Dices",
    "Directions",
    "Embedded Images",
    "Figure Matrix",
    "Input-Output",
    "Mirror and Water Images",
    "Odd One Out",
    "Picture Series and Sequences",
    "Paper Folding",
    "Puzzles",
    "Pattern Series and Sequences",
    "Order & Ranking",
    "Seating Arrangements",
    "Shape Construction",
    "Statement and Assumptions",
    "Statement and Conclusions",
    "Syllogism",

    # Quantitative Aptitude (31-72)
    "Algebra",
    "Alligations and mixtures",
    "Area",
    "Problems on Age",
    "Averages, Mean, Median and Mode",
    "Boat Problems",
    "Chain rule",
    "Discount",
    "Data Interpretation",
    "Games and Races",
    "Heights and distances",
    "Inequalities",
    "Number Series",
    "LCM and HCF",
    "Linear Equations",
    "Logarithms",
    "Number theory",
    "Number System – Fractions, Decimals",
    "Partnerships",
    "Percentage",
    "Permutation and Combinations",
    "Pipes and Cisterns",
    "Points, lines and angles",
    "Probability",
    "Profit and Loss",
    "Progressions",
    "Quadratic Equations",
    "Ratio and Proportions",
    "Remainder theorem and unit digit",
    "Sets and Venn Diagrams",
    "Simple and Compound Interest",
    "Simplification and Approximation",
    "Speed, Distance and Time",
    "Stocks and shares",
    "Data Sufficiency",
    "Surds, Indices, Exponents, and Powers",
    "Surface area",
    "Time and Work",
    "Problems on Train",
    "Trigonometry",
    "Volumes",
    "Work and Wages"
]

# %%
df = pd.read_excel("logical_qns_videos_5min.xlsx")
df = pd.DataFrame(df)
df
# Out:
#                                                   link                topic  \
# 0    https://www.youtube.com/watch?v=gXBuL_FyahE&t=...  Alphanumeric series
# 1    https://www.youtube.com/watch?v=ka2fuIyrRZY&pp...  Alphanumeric series
# 2    https://www.youtube.com/watch?v=co_6LHwUdqc&pp...  Alphanumeric series
# 3    https://www.youtube.com/watch?v=exAPyTTZ2uU&pp...  Alphanumeric series
# 4    https://www.youtube.com/watch?v=3cZFoiDcpTY&pp...  Alphanumeric series
# ..                                                 ...                  ...
# 329  https://www.youtube.com/watch?v=8OOBo5C7dsc&t=...       Work and Wages
# 330  https://www.youtube.com/watch?v=I-mmRzLdrxw&pp...       Work and Wages
# 331  https://www.youtube.com/watch?v=KE7tQf9spPg&pp...       Work and Wages
# 332  https://www.youtube.com/watch?v=lr4PAj8E0Vs&pp...       Work and Wages
# 333  https://www.youtube.com/watch?v=yAMCsmAdWR8&pp...       Work and Wages
#
#     likes views  upload_year   subscriber_count  \
# 0     28K  1.5M       2018.0  1.21M subscribers
# 1     15K  393K          NaN  8.67M subscribers
# 2      1K   52K       2023.0   475K subscribers
# 3    9.7K  348K          NaN  1.14M subscribers
# 4    1.9K   76K          NaN  1.73M subscribers
# ..    ...   ...          ...                ...
# 329  6.8K  498K       2018.0  1.21M subscribers
# 330   19K  1.2M       2018.0  1.73M subscribers
# 331   54K  3.3M       2018.0  1.21M subscribers
# 332     1    39       2023.0     49 subscribers
# 333     1    36       2020.0     29 subscribers
#
#                                                  title duration  \
# 0    Series - Tricks & Shortcuts for Placement test...      NaN
# 1    Alphanumeric Series Reasoning Tricks and Conce...      NaN
# 2    ALPHA NUMERIC SERIES - A TO Z BEGINNERS SERIES...      NaN
# 3    NUMBER SERIES BEST SHORT TRICKS FOR ALL BANK, ...      NaN
# 4    Element Series - 10 Types - Reasoning Ability ...      NaN
# ..                                                 ...      ...
# 329  Work and Wages - Shortcuts & Tricks for Placem...      NaN
# 330         TIME AND WORK _ Work and Wages _ Lesson #4      NaN
# 331  Time and Work - Shortcuts & Tricks for Placeme...      NaN
# 332  Time and Work | Part 7 | Work and Wages | Apti...      NaN
# 333     Work and Wages #Aptitude #Work #Wage #Shortcut      NaN
#
#                                            description        channel_name
# 0    Crack the logical reasoning section of Placeme...          CareerRide
# 1    Alphanumeric Series Reasoning Tricks and Conce...            Adda247
# 2                                       Royale pass :      Crack with Jack
# 3                         #Onlineclasses_CL_9676578793      Chandan Logics
# 4                                     #feelfreetolearn  Feel Free to Learn
# ..                                                 ...                 ...
# 329  Crack the quantitative aptitude section of Pla...          CareerRide
# 330                                   #FeelFreetoLearn  Feel Free to Learn
# 331  Crack the quantitative aptitude section of Pla...          CareerRide
# 332  Time and Work | Part 7 | Work and Wages | Apti...            Tutoralz
# 333                                              #Work       Elite Careers
#
# [334 rows x 10 columns]

# %%
df_topics = list(df["topic"].unique())
df_topics
# Out:
# ['Alphanumeric series',
#  'Reasoning Analogies',
#  'Artificial Language',
#  'Blood Relations',
#  'Calendars',
#  'Cause and Effect',
#  'Clocks',
#  'Coding-Decoding',
#  'Critical path',
#  'Cubes and cuboids',
#  'Data Sufficiency',
#  'Decision Making',
#  'Deductive Reasoning/Statement Analysis',
#  'Dices',
#  'Directions',
#  'Embedded Images',
#  'Alligations and mixtures',
#  'Area',
#  'Problems on Age',
#  'Averages, Mean, Median and Mode',
#  'Boat Problems',
#  'Chain rule',
#  'Discount',
#  'Data Interpretation',
#  'Games and Races',
#  'Heights and distances',
#  'Inequalities',
#  'Number Series',
#  'LCM and HCF',
#  'Linear Equations',
#  'Logarithms',
#  'Number theory',
#  nan,
#  'Profit and Loss',
#  'Progressions',
#  'Quadratic Equations',
#  'Ratio and Proportions',
#  'Remainder theorem and unit digit',
#  'Sets and Venn Diagrams',
#  'Simple and Compound Interest',
#  'Simplification and Approximation',
#  'Speed, Distance and Time',
#  'Stocks and shares',
#  'Surds, Indices, Exponents, and Powers',
#  'Surface area',
#  'Time and Work',
#  'Problems on Train',
#  'Trigonometry']

# %%
from logging import exception
from time import sleep
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options


import re
from datetime import datetime

final_video_details = []
for topic in topics:
  if topic in uni:
    continue
  try :
    url = f'https://www.youtube.com/results?search_query=Aptitude+and+Reasoning+{topic}+&sp=EgQQARgC'

    driver = webdriver.Chrome(service=service, options=chrome_options)
    driver.get(url)
    sleep(10)

    videos = driver.find_elements(By.CSS_SELECTOR, "a#thumbnail")
    video_links = [video.get_attribute("href") for video in videos]



    if len(video_links) > 5:
        video_links = video_links[:5]

    for video in video_links:
        video_data = {}
        try:
            driver = webdriver.Chrome(service=service, options=chrome_options)
            driver.get(video)
            sleep(16)

            video_data['link'] = video
            video_data["topic"] = topic



            try:
                # Likes\

                like_element = driver.find_element(By.CLASS_NAME, "ytLikeButtonViewModelHost")
                like_element = like_element.find_element(By.CLASS_NAME, "yt-spec-button-shape-next__button-text-content")
                like_count = like_element.text
                video_data["likes"] = like_count
            except Exception as e:
                print("Like count not found!", e)

            # Views
            view_elem = driver.find_element(By.ID, "info-container")
            view_elem = view_elem.find_elements(By.ID, "info")
            text = view_elem[0].text
            views_match = re.search(r"([\d\.]+[KM]?) views", text)
            views = views_match.group(1) if views_match else None
            video_data["views"] = views

            # Year
            years_ago_match = re.search(r"(\d+) years ago", text)
            years_ago = int(years_ago_match.group(1)) if years_ago_match else 0
            current_year = datetime.now().year
            upload_year = current_year - years_ago if years_ago else None
            video_data["upload_year"] = upload_year

            # Subscriber Count
            sub = driver.find_element(By.ID, "owner-sub-count")
            sub_count = sub.text
            video_data["subscriber_count"] = sub_count

            # Title
            tit = driver.find_element(By.ID, "above-the-fold")
            tit = tit.find_element(By.ID, "title")
            title = tit.text
            video_data["title"] = title

            # Duration
            dur = driver.find_element(By.CLASS_NAME, "ytp-time-duration")
            duration = dur.text
            video_data["duration"] = duration

            # Description
            des = driver.find_element(By.ID, "description-inline-expander")
            des = des.find_element(By.CLASS_NAME, "yt-core-attributed-string--link-inherit-color")
            description = des.text
            video_data["description"] = description

            #Channel Name
            chan = driver.find_element(By.ID, "upload-info")
            chan = chan.find_element(By.CSS_SELECTOR,"a.yt-simple-endpoint.style-scope.yt-formatted-string")
            channel_name = chan.text
            video_data["channel_name"] = channel_name

        except Exception as e:
            print("Error processing video", e)

        print(video_data)
        final_video_details.append(video_data)

  except Exception as e :
    print(e)
print(final_video_details)
# Out:
# {'link': 'https://www.youtube.com/watch?v=tnc9ojITRg4&pp=ygU9QXB0aXR1ZGUgYW5kIFJlYXNvbmluZyBOdW1iZXIgU3lzdGVtIOKAkyBGcmFjdGlvbnMsIERlY2ltYWxzIA%3D%3D', 'topic': 'Number System – Fractions, Decimals', 'likes': '62K', 'views': '4M', 'upload_year': 2018, 'subscriber_count': '1.21M subscribers', 'title': 'Fractions and Decimals - Shortcuts & Tricks for Placement Tests, Job Interviews & Exams', 'duration': '', 'description': 'Crack the quantitative aptitude section of Placement Test or Job Interview at any company with shortcuts & tricks on Fractions and Decimals. Extremely helpful to crack entrance exams like MBA, Banking – IBPS, SBI, UPSC, SSC, Railways etc.', 'channel_name': 'CareerRide'}
# {'link': 'https://www.youtube.com/watch?v=exAPyTTZ2uU&pp=ygU9QXB0aXR1ZGUgYW5kIFJlYXNvbmluZyBOdW1iZXIgU3lzdGVtIOKAkyBGcmFjdGlvbnMsIERlY2ltYWxzIA%3D%3D', 'topic': 'Number System – Fractions, Decimals', 'likes': '9.7K', 'views': '348K', 'upload_year': None, 'subscriber_count': '1.14M subscribers', 'title': 'NUMBER SERIES BEST SHORT TRICKS FOR ALL BANK, SSC, RAILWAY, DEFENCE , GROUPS & OTHER EXAMS', 'duration': '', 'description': '#Onlineclasses_CL_9676578793', 'channel_name': 'Chandan Logics'}
# {'link': 'https://www.youtube.com/watch?v=lJcARZaV8Ok&pp=ygU9QXB0aXR1ZGUgYW5kIFJlYXNvbmluZyBOdW1iZXIgU3lzdGVtIOKAkyBGcmFjdGlvbnMsIERlY2ltYWxzIA%3D%3D', 'topic': 'Number System – Fractions, Decimals', 'likes': '8.2K', 'views': '218K', 'upload_year': None, 'subscriber_count': '1.14M subscribers', 'title': 'LCM & HCF | BEST 2 SEC TRICKS FOR ALL SSC, BANK, RRB, AP/TS SI & GROUPS EXAMS | By Chandan Venna', 'duration': '', 'description': '#Onlineclasses_CL_9676578793', 'channel_name': 'Chandan Logics'}
# {'link': 'https://www.youtube.com/watch?v=OO0UCbwoQHU&pp=ygU9QXB0aXR1ZGUgYW5kIFJlYXNvbmluZyBOdW1iZXIgU3lzdGVtIOKAkyBGcmFjdGlvbnMsIERlY2ltYWxzIA%3D%3D', 'topic': 'Number System – Fractions, Decimals', 'likes': '16K', 'views': '602K', 'upload_year': 2020, 'subscriber_count': '1.14M subscribers', 'title': 'FRACTION TO PERCENTAGE CONCEPT & TRICKS | SSC | BANK | RRB | SI | GROUPS | CSAT | By Chandan Venna', 'duration': '', 'description': '#Onlineclasses_CL', 'channel_name': 'Chandan Logics'}
# {'link': 'https://www.youtube.com/watch?v=ncxdG4w91dk&pp=ygU9QXB0aXR1ZGUgYW5kIFJlYXNvbmluZyBOdW1iZXIgU3lzdGVtIOKAkyBGcmFjdGlvbnMsIERlY2ltYWxzIA%3D%3D', 'topic': 'Number System – Fractions, Decimals', 'likes': '19K', 'views': '321K', 'upload_year': 2023, 'subscriber_count': '656K subscribers', 'title': 'Decimal Fraction/Decimal Basic Concept & Tricks/Repeated Questions/Convert/Decimal Operations/Day 3', 'duration': '', 'description': '#mathclassday3', 'channel_name': 'Chinmaya Panda'}
# {'link': 'https://www.youtube.com/watch?v=hn9TKnr8L_8&pp=ygUkQXB0aXR1ZGUgYW5kIFJlYXNvbmluZyBQYXJ0bmVyc2hpcHMg', 'topic': 'Partnerships', 'likes': '11K', 'views': '595K', 'upload_year': 2018, 'subscriber_count': '1.21M subscribers', 'title': 'Partnership - Shortcuts & Tricks for Placement Tests, Job Interviews & Exams', 'duration': '', 'description': 'Crack the quantitative aptitude section of Placement Test or Job Interview at any company with shortcuts & tricks on Partnership. Extremely helpful to crack entrance exams like MBA, Banking – IBPS, SBI, UPSC, SSC, Railways etc.', 'channel_name': 'CareerRide'}
# {'link': 'https://www.youtube.com/watch?v=cYC8nyUaCbE&pp=ygUkQXB0aXR1ZGUgYW5kIFJlYXNvbmluZyBQYXJ0bmVyc2hpcHMg0gcJCX4JAYcqIYzv', 'topic': 'Partnerships', 'likes': '1', 'views': '16', 'upload_year': 2021, 'subscriber_count': '3.84K subscribers', 'title': 'Partnership - Quantitative Aptitude and Reasoning | Basics, Methods, Shortcuts & Tricks - Epatya', 'duration': '', 'description': "Epatya is India's No.1 Site for preparation of various competitive exams like UPSC, SSC CGL, SSC CHSL, RRB, APPSC, TSPSC, KAS etc. We have Unlimited Questions  for Practice and it's One stop solution for all competitive exams.", 'channel_name': 'epatya lectures'}
# {'link': 'https://www.youtube.com/watch?v=OSZ4MhDHG64&pp=ygUkQXB0aXR1ZGUgYW5kIFJlYXNvbmluZyBQYXJ0bmVyc2hpcHMg', 'topic': 'Partnerships', 'likes': '4.8K', 'views': '174K', 'upload_year': 2023, 'subscriber_count': '1.14M subscribers', 'title': '🔴LIVE🔴PARTNERSHIP BEST TRICKS | BANK | SSC | RAILWAY | CSAT | APPSC | TSPSC GROUP -4 | AP / TS SI', 'duration': '', 'description': '#Onlineclasses_CL_9676578793', 'channel_name': 'Chandan Logics'}
# {'link': 'https://www.youtube.com/watch?v=a9YG_qzhwPw&pp=ygUkQXB0aXR1ZGUgYW5kIFJlYXNvbmluZyBQYXJ0bmVyc2hpcHMg', 'topic': 'Partnerships', 'likes': '1.8K', 'views': '64K', 'upload_year': 2021, 'subscriber_count': '492K subscribers', 'title': 'Partnership in Telugu || Aptitude in Telugu || Root Maths Academy', 'duration': '', 'description': '#PartnershipinTelugu', 'channel_name': 'Vedantu Manabadi'}
# {'link': 'https://www.youtube.com/watch?v=xy4MFvynkzU&pp=ygUkQXB0aXR1ZGUgYW5kIFJlYXNvbmluZyBQYXJ0bmVyc2hpcHMg', 'topic': 'Partnerships', 'likes': 'Like', 'views': '11', 'upload_year': None, 'subscriber_count': '209 subscribers', 'title': 'Partnership | Master Aptitude | Quantitative Aptitude | Logical Reasoning | Complete Aptitude Course', 'duration': '', 'description': 'Partnerships | Master Aptitude | Quantitative Aptitude | Logical Reasoning | Complete Aptitude Course\n\nInstall Our App:', 'channel_name': 'TabishAbbasiDev'}
# {'link': 'https://www.youtube.com/watch?v=RWdNhJWwzSs&pp=ygUiQXB0aXR1ZGUgYW5kIFJlYXNvbmluZyBQZXJjZW50YWdlIA%3D%3D', 'topic': 'Percentage', 'likes': '41K', 'views': '2.4M', 'upload_year': 2018, 'subscriber_count': '1.21M subscribers', 'title': 'Percentage - Shortcuts & Tricks for Placement Tests, Job Interviews & Exams', 'duration': '', 'description': 'Crack the quantitative aptitude section of Placement Test or Job Interview at any company with shortcuts & tricks on Percentage. Extremely helpful to crack entrance exams like MBA, Banking – IBPS, SBI, UPSC, SSC, Railways etc.', 'channel_name': 'CareerRide'}
# {'link': 'https://www.youtube.com/watch?v=E5IkT1-Tiaw&pp=ygUiQXB0aXR1ZGUgYW5kIFJlYXNvbmluZyBQZXJjZW50YWdlIA%3D%3D', 'topic': 'Percentage', 'likes': '15K', 'views': '501K', 'upload_year': 2023, 'subscriber_count': '1.14M subscribers', 'title': '🔴LIVE🔴PERCENTAGE BEST TRICKS | BANK | SSC | RAILWAY | CSAT | APPSC | TSPSC DAO & ALL OTHER EXAMS', 'duration': '', 'description': '#Onlineclasses_CL_9676578793', 'channel_name': 'Chandan Logics'}
# {'link': 'https://www.youtube.com/watch?v=I9O16sqdK6Q&pp=ygUiQXB0aXR1ZGUgYW5kIFJlYXNvbmluZyBQZXJjZW50YWdlIA%3D%3D', 'topic': 'Percentage', 'likes': '12K', 'views': '561K', 'upload_year': 2021, 'subscriber_count': '1.14M subscribers', 'title': 'PERCENTAGE INTRO PART -1 |USEFUL FOR SSC | BANK | RRB | CAT|DEFENCE |AFCAT & OTHER COMPETITIVE EXAMS', 'duration': '', 'description': '#Onlineclasses_CL', 'channel_name': 'Chandan Logics'}
# {'link': 'https://www.youtube.com/watch?v=Oo5erc6C3GY&pp=ygUiQXB0aXR1ZGUgYW5kIFJlYXNvbmluZyBQZXJjZW50YWdlIA%3D%3D', 'topic': 'Percentage', 'likes': '3.6K', 'views': '102K', 'upload_year': None, 'subscriber_count': '245K subscribers', 'title': 'PERCENTAGES : శాతాలు || Income and Election Based Models || BEST CONCEPTS || BEST ARITHMETIC BOOK', 'duration': '', 'description': '👉 BUY 2 BOOKS : 700 /- \n(Arithmetic + Reasoning)', 'channel_name': 'SIDDU STUDY CIRCLE'}
# {'link': 'https://www.youtube.com/watch?v=h3ek0Y3886E&pp=ygUiQXB0aXR1ZGUgYW5kIFJlYXNvbmluZyBQZXJjZW50YWdlIA%3D%3D', 'topic': 'Percentage', 'likes': '2.5K', 'views': '43K', 'upload_year': 2023, 'subscriber_count': '207K subscribers', 'title': 'Percentage Aptitude Tricks || Target 2022 || by Sridhar TJ', 'duration': '', 'description': 'Students who are preparing for any competitive exams definitely this video useful for you. Number Series is the most important topic for all the bank exams. So try to practice regularly definitely you will crack the upcoming exams. ', 'channel_name': 'NE THUNIGA'}
# {'link': 'https://www.youtube.com/watch?v=_qoqJ2JKfjc&pp=ygU0QXB0aXR1ZGUgYW5kIFJlYXNvbmluZyBQZXJtdXRhdGlvbiBhbmQgQ29tYmluYXRpb25zIA%3D%3D', 'topic': 'Permutation and Combinations', 'likes': '15K', 'views': '730K', 'upload_year': 2020, 'subscriber_count': '1.93M subscribers', 'title': 'Aptitude Made Easy - Permutations Full Series - Learn maths #StayHome', 'duration': '', 'description': 'Get the latest interview tips,Job notifications,top MNC openings,placement papers and many more only at Freshersworld.com(www.freshersworld.com?src=Youtube).', 'channel_name': 'FreshCareers'}
# {'link': 'https://www.youtube.com/watch?v=ETiRE7N7pEI&pp=ygU0QXB0aXR1ZGUgYW5kIFJlYXNvbmluZyBQZXJtdXRhdGlvbiBhbmQgQ29tYmluYXRpb25zIA%3D%3D', 'topic': 'Permutation and Combinations', 'likes': '34K', 'views': '2.1M', 'upload_year': 2018, 'subscriber_count': '1.21M subscribers', 'title': 'Permutation and Combination - Shortcuts & Tricks for Placement Tests, Job Interviews & Exams', 'duration': '', 'description': 'Crack the quantitative aptitude section of Placement Test or Job Interview at any company with shortcuts & tricks on Permutation and Combination. Extremely helpful to crack entrance exams like MBA, Banking – IBPS, SBI, UPSC, SSC, Railways etc.', 'channel_name': 'CareerRide'}
# {'link': 'https://www.youtube.com/watch?v=tnF9f3zCCKI&pp=ygU0QXB0aXR1ZGUgYW5kIFJlYXNvbmluZyBQZXJtdXRhdGlvbiBhbmQgQ29tYmluYXRpb25zINIHCQl-CQGHKiGM7w%3D%3D', 'topic': 'Permutation and Combinations', 'likes': '14K', 'views': '775K', 'upload_year': 2020, 'subscriber_count': '428K subscribers', 'title': 'Permutations, Combinations & Probability (14 Word Problems)', 'duration': '', 'description': "Learn how to work with permutations, combinations and probability in the 14 word problems we go through in this video by Mario's Math Tutoring.  We discuss factorials and how to simplify factorial expressions as well as the fundamental counting principle.  We also discuss the formulas for nPr and nCr as they relate to per", 'channel_name': "Mario's Math Tutoring"}
# {'link': 'https://www.youtube.com/watch?v=gYT72Rzh3Iw&pp=ygU0QXB0aXR1ZGUgYW5kIFJlYXNvbmluZyBQZXJtdXRhdGlvbiBhbmQgQ29tYmluYXRpb25zIA%3D%3D', 'topic': 'Permutation and Combinations', 'likes': '618', 'views': '29K', 'upload_year': 2023, 'subscriber_count': '221K subscribers', 'title': 'PERMUTATION & COMBINATION | A to Z | INTRODUCTION & CONCEPT', 'duration': '', 'description': '60 days Preparation Strategy : ', 'channel_name': 'Radhina Quants'}
# {'link': 'https://www.youtube.com/watch?v=fD_jLOETAjg&pp=ygU0QXB0aXR1ZGUgYW5kIFJlYXNvbmluZyBQZXJtdXRhdGlvbiBhbmQgQ29tYmluYXRpb25zIA%3D%3D', 'topic': 'Permutation and Combinations', 'likes': '181', 'views': '8.7K', 'upload_year': 2023, 'subscriber_count': '42.7K subscribers', 'title': 'PERMUTATION & COMBINATION | Suresh IAS Academy', 'duration': '', 'description': 'SURESH IAS ACADEMY\nTNPSC   BANK    TET   RAILWAY    SSC     POLICE\nTUTICORIN      TIRUNELVELI      RAMANATHAPURAM     MADURAI', 'channel_name': 'SURESH BANKING'}
# {'link': 'https://www.youtube.com/watch?v=mBtBD1N7ywQ&pp=ygUqQXB0aXR1ZGUgYW5kIFJlYXNvbmluZyBQaXBlcyBhbmQgQ2lzdGVybnMg', 'topic': 'Pipes and Cisterns', 'likes': '12K', 'views': '773K', 'upload_year': 2018, 'subscriber_count': '1.21M subscribers', 'title': 'Pipes and Cisterns - Shortcuts & Tricks for Placement Tests, Job Interviews & Exams', 'duration': '', 'description': 'Crack the quantitative aptitude section of Placement Test or Job Interview at any company with shortcuts & tricks on Pipes and Cisterns. Extremely helpful to crack entrance exams like MBA, Banking – IBPS, SBI, UPSC, SSC, Railways etc.', 'channel_name': 'CareerRide'}
# {'link': 'https://www.youtube.com/watch?v=BJqpD1SeV1A&pp=ygUqQXB0aXR1ZGUgYW5kIFJlYXNvbmluZyBQaXBlcyBhbmQgQ2lzdGVybnMg', 'topic': 'Pipes and Cisterns', 'likes': '499', 'views': '15K', 'upload_year': 2023, 'subscriber_count': '445K subscribers', 'title': 'PIPES & TANKS -Tricks & Shortcuts to Solve within Few Minutes | TNPSC Group 2, 2A & 4 | Veranda Race', 'duration': '', 'description': 'முதல் முயற்சிலேயே TNPSC தேர்வில் வெற்றி பெற:\nFor Any Course Enquiry & To download free materials : ', 'channel_name': 'VERANDA RACE - TNPSC'}
# {'link': 'https://www.youtube.com/watch?v=S9LRVUOy2es&pp=ygUqQXB0aXR1ZGUgYW5kIFJlYXNvbmluZyBQaXBlcyBhbmQgQ2lzdGVybnMg', 'topic': 'Pipes and Cisterns', 'likes': '851', 'views': '12K', 'upload_year': None, 'subscriber_count': '1.14M subscribers', 'title': 'Pipes & Cisterns Latest PYQs 2024 | Best Short Tricks for BANK, SSC, RRB, APPSC, TGPSC & OTHER EXAMS', 'duration': '', 'description': '#onlineclasses_cl_9676578793', 'channel_name': 'Chandan Logics'}
# {'link': 'https://www.youtube.com/watch?v=EToNouSc7RE&pp=ygUqQXB0aXR1ZGUgYW5kIFJlYXNvbmluZyBQaXBlcyBhbmQgQ2lzdGVybnMg', 'topic': 'Pipes and Cisterns', 'likes': '33K', 'views': '882K', 'upload_year': 2023, 'subscriber_count': '1.14M subscribers', 'title': '🔴LIVE🔴REVISION CLASS TIME AND WORK 2 SEC TRICKS | BANK | SSC | RAILWAY | CSAT | APPSC | TSPSC DAO', 'duration': '', 'description': '#Onlineclasses_CL_9676578793', 'channel_name': 'Chandan Logics'}
# {'link': 'https://www.youtube.com/watch?v=CvIbz4x8CZs&pp=ygUqQXB0aXR1ZGUgYW5kIFJlYXNvbmluZyBQaXBlcyBhbmQgQ2lzdGVybnMg', 'topic': 'Pipes and Cisterns', 'likes': '46', 'views': '6.1K', 'upload_year': 2018, 'subscriber_count': '60.3K subscribers', 'title': 'Aptitude Training 6 | Tips and Tricks to solve Pipes and Cisterns | PlacementSeason', 'duration': '', 'description': 'Get the exclusive tips and tricks to solve problems based on pipes and cisterns in this webinar video\n\nIf you want to be in the loop with us Subscribe our channel.', 'channel_name': 'PlacementSeason'}
# {'link': 'https://www.youtube.com/watch?v=Bq1QyT-HZrU&pp=ygUwQXB0aXR1ZGUgYW5kIFJlYXNvbmluZyBQb2ludHMsIGxpbmVzIGFuZCBhbmdsZXMg', 'topic': 'Points, lines and angles', 'likes': '18K', 'views': '563K', 'upload_year': None, 'subscriber_count': '203K subscribers', 'title': 'ANGLE THEOREMS - Top 10 Must Know', 'duration': '', 'description': "Here are the top 10 most important angle theorems that you have to know to be successful in your math classes. This video covers angle theorems for various shapes including triangles and circles, and also parallel line theorems. Go to jensenmath.ca for FREE math resources and don't forget to subscribe to the chann", 'channel_name': 'JensenMath'}
# {'link': 'https://www.youtube.com/watch?v=CsyoFsx8PGg&pp=ygUwQXB0aXR1ZGUgYW5kIFJlYXNvbmluZyBQb2ludHMsIGxpbmVzIGFuZCBhbmdsZXMg', 'topic': 'Points, lines and angles', 'likes': '22', 'views': '973', 'upload_year': 2020, 'subscriber_count': '3.28K subscribers', 'title': 'Geometry - 1 (Lines & Angles)', 'duration': '', 'description': 'Geometry concept is very important in the lane of all competitive exams like SSC, Railways, Campus Recruitment etc.', 'channel_name': 'Aptitude World NATUS'}
# {'link': 'https://www.youtube.com/watch?v=pvn5SzkcQ5c&pp=ygUwQXB0aXR1ZGUgYW5kIFJlYXNvbmluZyBQb2ludHMsIGxpbmVzIGFuZCBhbmdsZXMg0gcJCX4JAYcqIYzv', 'topic': 'Points, lines and angles', 'likes': '31K', 'views': '735K', 'upload_year': 2021, 'subscriber_count': '2.23M subscribers', 'title': 'Geometry Trick | Lines and Angles | Maths Trick | Best For All Competitive Exam | imran sir maths', 'duration': '', 'description': 'Hello Friends\nThis is a awesome video for Geometry. You will get best concept of Lines and Angles after watching this', 'channel_name': 'imran sir maths'}
# {'link': 'https://www.youtube.com/watch?v=3FFI2Bm-obI&pp=ygUwQXB0aXR1ZGUgYW5kIFJlYXNvbmluZyBQb2ludHMsIGxpbmVzIGFuZCBhbmdsZXMg', 'topic': 'Points, lines and angles', 'likes': '6', 'views': '462', 'upload_year': 2017, 'subscriber_count': '4.29K subscribers', 'title': 'LINES AND ANGLES(Geometry) (Part 1) Angles, Degrees and Radians and Parallel Lines and Transversals', 'duration': '', 'description': 'Follow  us on Twitter = ', 'channel_name': 'Aptitude-Reasoning-Shortcuts-Tips-Tricks'}
# {'link': 'https://www.youtube.com/watch?v=VNEbhx4I6K8&pp=ygUwQXB0aXR1ZGUgYW5kIFJlYXNvbmluZyBQb2ludHMsIGxpbmVzIGFuZCBhbmdsZXMg0gcJCX4JAYcqIYzv', 'topic': 'Points, lines and angles', 'likes': '23', 'views': '436', 'upload_year': None, 'subscriber_count': '7.59K subscribers', 'title': 'Lines and Angles | GEOMETRY || CUET PG TISSNET MAHCET CMAT 2024 Prep Booster', 'duration': '', 'description': 'Lines and Angles | GEOMETRY || CUET PG TISSNET MAHCET CMAT 2024 Prep Booster || CUET MBA Preparation 2024 || CMAT MBA 2024 Quantitative Aptitude ', 'channel_name': 'MATHOLOGICAL'}
# [{'link': 'https://www.youtube.com/watch?v=tnc9ojITRg4&pp=ygU9QXB0aXR1ZGUgYW5kIFJlYXNvbmluZyBOdW1iZXIgU3lzdGVtIOKAkyBGcmFjdGlvbnMsIERlY2ltYWxzIA%3D%3D', 'topic': 'Number System – Fractions, Decimals', 'likes': '62K', 'views': '4M', 'upload_year': 2018, 'subscriber_count': '1.21M subscribers', 'title': 'Fractions and Decimals - Shortcuts & Tricks for Placement Tests, Job Interviews & Exams', 'duration': '', 'description': 'Crack the quantitative aptitude section of Placement Test or Job Interview at any company with shortcuts & tricks on Fractions and Decimals. Extremely helpful to crack entrance exams like MBA, Banking – IBPS, SBI, UPSC, SSC, Railways etc.', 'channel_name': 'CareerRide'}, {'link': 'https://www.youtube.com/watch?v=exAPyTTZ2uU&pp=ygU9QXB0aXR1ZGUgYW5kIFJlYXNvbmluZyBOdW1iZXIgU3lzdGVtIOKAkyBGcmFjdGlvbnMsIERlY2ltYWxzIA%3D%3D', 'topic': 'Number System – Fractions, Decimals', 'likes': '9.7K', 'views': '348K', 'upload_year': None, 'subscriber_count': '1.14M subscribers', 'title': 'NUMBER SERIES BEST SHORT TRICKS FOR ALL BANK, SSC, RAILWAY, DEFENCE , GROUPS & OTHER EXAMS', 'duration': '', 'description': '#Onlineclasses_CL_9676578793', 'channel_name': 'Chandan Logics'}, {'link': 'https://www.youtube.com/watch?v=lJcARZaV8Ok&pp=ygU9QXB0aXR1ZGUgYW5kIFJlYXNvbmluZyBOdW1iZXIgU3lzdGVtIOKAkyBGcmFjdGlvbnMsIERlY2ltYWxzIA%3D%3D', 'topic': 'Number System – Fractions, Decimals', 'likes': '8.2K', 'views': '218K', 'upload_year': None, 'subscriber_count': '1.14M subscribers', 'title': 'LCM & HCF | BEST 2 SEC TRICKS FOR ALL SSC, BANK, RRB, AP/TS SI & GROUPS EXAMS | By Chandan Venna', 'duration': '', 'description': '#Onlineclasses_CL_9676578793', 'channel_name': 'Chandan Logics'}, {'link': 'https://www.youtube.com/watch?v=OO0UCbwoQHU&pp=ygU9QXB0aXR1ZGUgYW5kIFJlYXNvbmluZyBOdW1iZXIgU3lzdGVtIOKAkyBGcmFjdGlvbnMsIERlY2ltYWxzIA%3D%3D', 'topic': 'Number System – Fractions, Decimals', 'likes': '16K', 'views': '602K', 'upload_year': 2020, 'subscriber_count': '1.14M subscribers', 'title': 'FRACTION TO PERCENTAGE CONCEPT & TRICKS | SSC | BANK | RRB | SI | GROUPS | CSAT | By Chandan Venna', 'duration': '', 'description': '#Onlineclasses_CL', 'channel_name': 'Chandan Logics'}, {'link': 'https://www.youtube.com/watch?v=ncxdG4w91dk&pp=ygU9QXB0aXR1ZGUgYW5kIFJlYXNvbmluZyBOdW1iZXIgU3lzdGVtIOKAkyBGcmFjdGlvbnMsIERlY2ltYWxzIA%3D%3D', 'topic': 'Number System – Fractions, Decimals', 'likes': '19K', 'views': '321K', 'upload_year': 2023, 'subscriber_count': '656K subscribers', 'title': 'Decimal Fraction/Decimal Basic Concept & Tricks/Repeated Questions/Convert/Decimal Operations/Day 3', 'duration': '', 'description': '#mathclassday3', 'channel_name': 'Chinmaya Panda'}, {'link': 'https://www.youtube.com/watch?v=hn9TKnr8L_8&pp=ygUkQXB0aXR1ZGUgYW5kIFJlYXNvbmluZyBQYXJ0bmVyc2hpcHMg', 'topic': 'Partnerships', 'likes': '11K', 'views': '595K', 'upload_year': 2018, 'subscriber_count': '1.21M subscribers', 'title': 'Partnership - Shortcuts & Tricks for Placement Tests, Job Interviews & Exams', 'duration': '', 'description': 'Crack the quantitative aptitude section of Placement Test or Job Interview at any company with shortcuts & tricks on Partnership. Extremely helpful to crack entrance exams like MBA, Banking – IBPS, SBI, UPSC, SSC, Railways etc.', 'channel_name': 'CareerRide'}, {'link': 'https://www.youtube.com/watch?v=cYC8nyUaCbE&pp=ygUkQXB0aXR1ZGUgYW5kIFJlYXNvbmluZyBQYXJ0bmVyc2hpcHMg0gcJCX4JAYcqIYzv', 'topic': 'Partnerships', 'likes': '1', 'views': '16', 'upload_year': 2021, 'subscriber_count': '3.84K subscribers', 'title': 'Partnership - Quantitative Aptitude and Reasoning | Basics, Methods, Shortcuts & Tricks - Epatya', 'duration': '', 'description': "Epatya is India's No.1 Site for preparation of various competitive exams like UPSC, SSC CGL, SSC CHSL, RRB, APPSC, TSPSC, KAS etc. We have Unlimited Questions  for Practice and it's One stop solution for all competitive exams.", 'channel_name': 'epatya lectures'}, {'link': 'https://www.youtube.com/watch?v=OSZ4MhDHG64&p ...

# %%
df = pd.DataFrame(final_video_details)
df.to_csv("final_video_details.csv", index=False)

# %%
uni = df['topic'].unique()
for topic in topics :
  if topic not in uni :
    print(topic)
# Out:
# Number System – Fractions, Decimals

# %%
df = pd.read_csv("final_video_details_3min_logical.csv")
df = pd.DataFrame(df)
df
# Out:
#                                                   link  \
# 0    https://www.youtube.com/watch?v=gi_7qz2Uljg&pp...
# 1    https://www.youtube.com/watch?v=HWySiF_OnhQ&pp...
# 2    https://www.youtube.com/watch?v=-e7rpdHWZMk&pp...
# 3    https://www.youtube.com/watch?v=w8p1kEnxlTM&pp...
# 4    https://www.youtube.com/watch?v=EddcDYxQ0HU&pp...
# ..                                                 ...
# 208  https://www.youtube.com/watch?v=Yn0215QMuO8&pp...
# 209  https://www.youtube.com/watch?v=B7VqoXjoHPk&pp...
# 210  https://www.youtube.com/watch?v=qTHktZoRcGA&pp...
# 211  https://www.youtube.com/watch?v=bgVqijWNYVM&pp...
# 212  https://www.youtube.com/watch?v=B-s7AMbslvE&pp...
#
#                                 topic likes views  upload_year  \
# 0                 Alphanumeric series  2.3K  120K          NaN
# 1                 Alphanumeric series    18   543       2020.0
# 2                 Alphanumeric series  2.2K   96K          NaN
# 3                 Reasoning Analogies    7K  262K       2019.0
# 4                 Reasoning Analogies  6.3K  356K       2020.0
# ..                                ...   ...   ...          ...
# 208      Simple and Compound Interest  5.7K  339K       2019.0
# 209      Simple and Compound Interest   17K  856K       2021.0
# 210  Simplification and Approximation   15K  295K       2021.0
# 211  Simplification and Approximation     1    48       2017.0
# 212  Simplification and Approximation    63  3.4K       2017.0
#
#       subscriber_count                                              title  \
# 0    1.73M subscribers  Alphanumeric Series Explanation - Reasoning Ab...
# 1    2.37K subscribers  Logical Reasoning - Alphanumeric Sequence - Pa...
# 2     495K subscribers  Alphanumeric series (Reasoning Ability) || All...
# 3     475K subscribers  Reasoning trick - Analogy | RRB NTPC | Mr.Jackson
# 4    4.83M subscribers  ANALOGY TEST Questions, Tips, Tricks and ANSWE...
# ..                 ...                                                ...
# 208  1.93M subscribers  Aptitude Made Easy - Compound interest – Basic...
# 209  1.73M subscribers  Simple Interest || Introduction (Part-1) ||Qua...
# 210  2.23M subscribers  Simplification | Simplification Tricks in Math...
# 211     23 subscribers   10.Simplification and Approximations Problems-VI
# 212    52K subscribers  How to Solve Simplification & Approximation Qu...
#
#     duration                                        description  \
# 0      00:25                                   #feelfreetolearn
# 1        NaN  Visit www.completembacetcourse.com for access ...
# 2        NaN                              #feelfreetolearntamil
# 3        NaN                                  Registration link
# 4        NaN  Get access to Richard's FREE Online Psychometr...
# ..       ...                                                ...
# 208      NaN  Get the latest interview tips,Job notification...
# 209      NaN                                   #FeelFreetoLearn
# 210      NaN                              Simplification Tricks
# 211      NaN  Part 6 of Simplification and Approximations Pr...
# 212      NaN  How to Solve "Simplification & Approximation" ...
#
#               channel_name
# 0       Feel Free to Learn
# 1       CareerWise Mentors
# 2    FeelFreetoLearn_தமிழ்
# 3          Crack with Jack
# 4               CareerVidz
# ..                     ...
# 208           FreshCareers
# 209     Feel Free to Learn
# 210        imran sir maths
# 211         Entrance Tutor
# 212          Study Capsule
#
# [213 rows x 10 columns]

# %%
rows = df[df['link'].isna()]
rows
# Out:
# Empty DataFrame
# Columns: [link, topic, likes, views, upload_year, subscriber_count, title, duration, description, channel_name]
# Index: []

# %%
google_rows = df[df['link'].astype(str).str.contains("google", na=False)]


google_rows
# Out:
#                                                   link  \
# 129  https://www.googleadservices.com/pagead/aclk?s...
# 144  https://www.googleadservices.com/pagead/aclk?s...
#
#                                    topic likes views  upload_year  \
# 129  Number System – Fractions, Decimals   NaN   NaN          NaN
# 144                    Stocks and shares   193   10K          NaN
#
#       subscriber_count                                    title duration  \
# 129                NaN                                      NaN      NaN
# 144  2.59K subscribers  I Developed an AI Trading Bot\nUnlisted      NaN
#
#                                            description  channel_name
# 129                                                NaN           NaN
# 144  Here are step-by-step instructions to make you...  Todd Watkins

# %%
df = df.drop(google_rows.index)
df
# Out:
#                                                   link  \
# 0    https://www.youtube.com/watch?v=gi_7qz2Uljg&pp...
# 1    https://www.youtube.com/watch?v=HWySiF_OnhQ&pp...
# 2    https://www.youtube.com/watch?v=-e7rpdHWZMk&pp...
# 3    https://www.youtube.com/watch?v=w8p1kEnxlTM&pp...
# 4    https://www.youtube.com/watch?v=EddcDYxQ0HU&pp...
# ..                                                 ...
# 208  https://www.youtube.com/watch?v=Yn0215QMuO8&pp...
# 209  https://www.youtube.com/watch?v=B7VqoXjoHPk&pp...
# 210  https://www.youtube.com/watch?v=qTHktZoRcGA&pp...
# 211  https://www.youtube.com/watch?v=bgVqijWNYVM&pp...
# 212  https://www.youtube.com/watch?v=B-s7AMbslvE&pp...
#
#                                 topic likes views  upload_year  \
# 0                 Alphanumeric series  2.3K  120K          NaN
# 1                 Alphanumeric series    18   543       2020.0
# 2                 Alphanumeric series  2.2K   96K          NaN
# 3                 Reasoning Analogies    7K  262K       2019.0
# 4                 Reasoning Analogies  6.3K  356K       2020.0
# ..                                ...   ...   ...          ...
# 208      Simple and Compound Interest  5.7K  339K       2019.0
# 209      Simple and Compound Interest   17K  856K       2021.0
# 210  Simplification and Approximation   15K  295K       2021.0
# 211  Simplification and Approximation     1    48       2017.0
# 212  Simplification and Approximation    63  3.4K       2017.0
#
#       subscriber_count                                              title  \
# 0    1.73M subscribers  Alphanumeric Series Explanation - Reasoning Ab...
# 1    2.37K subscribers  Logical Reasoning - Alphanumeric Sequence - Pa...
# 2     495K subscribers  Alphanumeric series (Reasoning Ability) || All...
# 3     475K subscribers  Reasoning trick - Analogy | RRB NTPC | Mr.Jackson
# 4    4.83M subscribers  ANALOGY TEST Questions, Tips, Tricks and ANSWE...
# ..                 ...                                                ...
# 208  1.93M subscribers  Aptitude Made Easy - Compound interest – Basic...
# 209  1.73M subscribers  Simple Interest || Introduction (Part-1) ||Qua...
# 210  2.23M subscribers  Simplification | Simplification Tricks in Math...
# 211     23 subscribers   10.Simplification and Approximations Problems-VI
# 212    52K subscribers  How to Solve Simplification & Approximation Qu...
#
#     duration                                        description  \
# 0      00:25                                   #feelfreetolearn
# 1        NaN  Visit www.completembacetcourse.com for access ...
# 2        NaN                              #feelfreetolearntamil
# 3        NaN                                  Registration link
# 4        NaN  Get access to Richard's FREE Online Psychometr...
# ..       ...                                                ...
# 208      NaN  Get the latest interview tips,Job notification...
# 209      NaN                                   #FeelFreetoLearn
# 210      NaN                              Simplification Tricks
# 211      NaN  Part 6 of Simplification and Approximations Pr...
# 212      NaN  How to Solve "Simplification & Approximation" ...
#
#               channel_name
# 0       Feel Free to Learn
# 1       CareerWise Mentors
# 2    FeelFreetoLearn_தமிழ்
# 3          Crack with Jack
# 4               CareerVidz
# ..                     ...
# 208           FreshCareers
# 209     Feel Free to Learn
# 210        imran sir maths
# 211         Entrance Tutor
# 212          Study Capsule
#
# [211 rows x 10 columns]

# %%
df = df.sort_values(by='topic')
df
# Out:
#                                                   link  \
# 76   https://www.youtube.com/watch?v=3qSQGOzFUiA&pp...
# 78   https://www.youtube.com/watch?v=owanjQL07us&pp...
# 77   https://www.youtube.com/watch?v=Ik6M-hOkP8A&pp...
# 79   https://www.youtube.com/watch?v=ovX2siB6xLc&pp...
# 80   https://www.youtube.com/watch?v=u1OzWJh8Y6g&pp...
# ..                                                 ...
# 166  https://www.youtube.com/watch?v=tuI7B8o9Ve4&pp...
# 167  https://www.youtube.com/watch?v=VUPTtniHbEY&pp...
# 168  https://www.youtube.com/watch?v=Ajn288_rB-E&pp...
# 170  https://www.youtube.com/watch?v=GDNwQFKgsys&pp...
# 169  https://www.youtube.com/watch?v=5iYvg3_-VTw&pp...
#
#                         topic likes views  upload_year   subscriber_count  \
# 76                    Algebra    15   861       2020.0   677K subscribers
# 78                    Algebra  7.5K  359K          NaN   161K subscribers
# 77                    Algebra    74  5.2K       2020.0   677K subscribers
# 79   Alligations and mixtures   126  5.2K       2018.0   677K subscribers
# 80   Alligations and mixtures    44  6.5K       2017.0   677K subscribers
# ..                        ...   ...   ...          ...                ...
# 166                   Volumes    32  7.2K       2015.0  2.26M subscribers
# 167                   Volumes   68K  2.1M       2021.0  2.23M subscribers
# 168            Work and Wages   44K  943K          NaN  2.23M subscribers
# 170            Work and Wages   39K  2.5M       2018.0   520K subscribers
# 169            Work and Wages     4   225       2023.0    63K subscribers
#
#                                                  title duration  \
# 76   Algebra | Additional Example 27 and 28 | Quant...      NaN
# 78   NUMERICAL ABILITY REVIEWER | Math Random Problems      NaN
# 77   Algebra | Introduction to Algebra | Basic Exam...      NaN
# 79   Alligations and Mixtures | Additional Example ...      NaN
# 80   Alligations and Mixtures | Advanced Example - ...      NaN
# ..                                                 ...      ...
# 166  Numerical reasoning : Volume and surface area ...      NaN
# 167  Mensuration Maths Tricks | Surface Area Formul...      NaN
# 168  Time & Work Trick | Maths Tricks | imran sir m...      NaN
# 170  Time and Work Problems Shortcut & Tricks (Part...      NaN
# 169  Time and Work Wages Examples || Lesson 4.6 || ...      NaN
#
#                                            description  \
# 76                                        Subscribe @
# 78   NUMERICAL ABILITY REVIEWER Math Random Problem...
# 77   In this TalentSprint sesion on Algebra, our te...
# 79                                        Subscribe @
# 80                                        Subscribe @
# ..                                                 ...
# 166  This tutorial is about Quantitative aptitude a...
# 167  Hello Friends \nIn this video following points...
# 168                                 Buy Link Amazon –
# 170  In this video I will teach you 1 special Trick...
# 169  Time and Work Wages Examples\nIn this class, W...
#
#                    channel_name
# 76   TalentSprint Aptitude Prep
# 78                  NoMo Studio
# 77   TalentSprint Aptitude Prep
# 79   TalentSprint Aptitude Prep
# 80   TalentSprint Aptitude Prep
# ..                          ...
# 166             Shomu's Biology
# 167             imran sir maths
# 168             imran sir maths
# 170      Smart Study for Career
# 169             Learning Monkey
#
# [211 rows x 10 columns]

# %%
df = df.reset_index(drop=True)
df
# Out:
# /usr/local/lib/python3.11/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#                                                   link  \
# 0    https://www.youtube.com/watch?v=3qSQGOzFUiA&pp...
# 1    https://www.youtube.com/watch?v=owanjQL07us&pp...
# 2    https://www.youtube.com/watch?v=Ik6M-hOkP8A&pp...
# 3    https://www.youtube.com/watch?v=ovX2siB6xLc&pp...
# 4    https://www.youtube.com/watch?v=u1OzWJh8Y6g&pp...
# ..                                                 ...
# 206  https://www.youtube.com/watch?v=tuI7B8o9Ve4&pp...
# 207  https://www.youtube.com/watch?v=VUPTtniHbEY&pp...
# 208  https://www.youtube.com/watch?v=Ajn288_rB-E&pp...
# 209  https://www.youtube.com/watch?v=GDNwQFKgsys&pp...
# 210  https://www.youtube.com/watch?v=5iYvg3_-VTw&pp...
#
#                         topic likes views  upload_year   subscriber_count  \
# 0                     Algebra    15   861       2020.0   677K subscribers
# 1                     Algebra  7.5K  359K          NaN   161K subscribers
# 2                     Algebra    74  5.2K       2020.0   677K subscribers
# 3    Alligations and mixtures   126  5.2K       2018.0   677K subscribers
# 4    Alligations and mixtures    44  6.5K       2017.0   677K subscribers
# ..                        ...   ...   ...          ...                ...
# 206                   Volumes    32  7.2K       2015.0  2.26M subscribers
# 207                   Volumes   68K  2.1M       2021.0  2.23M subscribers
# 208            Work and Wages   44K  943K          NaN  2.23M subscribers
# 209            Work and Wages   39K  2.5M       2018.0   520K subscribers
# 210            Work and Wages     4   225       2023.0    63K subscribers
#
#                                                  title duration  \
# 0    Algebra | Additional Example 27 and 28 | Quant...      NaN
# 1    NUMERICAL ABILITY REVIEWER | Math Random Problems      NaN
# 2    Algebra | Introduction to Algebra | Basic Exam...      NaN
# 3    Alligations and Mixtures | Additional Example ...      NaN
# 4    Alligations and Mixtures | Advanced Example - ...      NaN
# ..                                                 ...      ...
# 206  Numerical reasoning : Volume and surface area ...      NaN
# 207  Mensuration Maths Tricks | Surface Area Formul...      NaN
# 208  Time & Work Trick | Maths Tricks | imran sir m...      NaN
# 209  Time and Work Problems Shortcut & Tricks (Part...      NaN
# 210  Time and Work Wages Examples || Lesson 4.6 || ...      NaN
#
#                                            description  \
# 0                                         Subscribe @
# 1    NUMERICAL ABILITY REVIEWER Math Random Problem...
# 2    In this TalentSprint sesion on Algebra, our te...
# 3                                         Subscribe @
# 4                                         Subscribe @
# ..                                                 ...
# 206  This tutorial is about Quantitative aptitude a...
# 207  Hello Friends \nIn this video following points...
# 208                                 Buy Link Amazon –
# 209  In this video I will teach you 1 special Trick...
# 210  Time and Work Wages Examples\nIn this class, W...
#
#                    channel_name
# 0    TalentSprint Aptitude Prep
# 1                   NoMo Studio
# 2    TalentSprint Aptitude Prep
# 3    TalentSprint Aptitude Prep
# 4    TalentSprint Aptitude Prep
# ..                          ...
# 206             Shomu's Biology
# 207             imran sir maths
# 208             imran sir maths
# 209      Smart Study for Career
# 210             Learning Monkey
#
# [211 rows x 10 columns]

# %%
df2 = pd.read_excel("logical_qns_videos_5min.xlsx")
df2 = pd.DataFrame(df2)
df2
# Out:
#                                                   link  \
# 0    https://www.youtube.com/watch?v=gXBuL_FyahE&t=...
# 1    https://www.youtube.com/watch?v=ka2fuIyrRZY&pp...
# 2    https://www.youtube.com/watch?v=co_6LHwUdqc&pp...
# 3    https://www.youtube.com/watch?v=exAPyTTZ2uU&pp...
# 4    https://www.youtube.com/watch?v=3cZFoiDcpTY&pp...
# ..                                                 ...
# 355  https://www.youtube.com/watch?v=Bq1QyT-HZrU&pp...
# 356  https://www.youtube.com/watch?v=CsyoFsx8PGg&pp...
# 357  https://www.youtube.com/watch?v=pvn5SzkcQ5c&pp...
# 358  https://www.youtube.com/watch?v=3FFI2Bm-obI&pp...
# 359  https://www.youtube.com/watch?v=VNEbhx4I6K8&pp...
#
#                         topic likes views  upload_year   subscriber_count  \
# 0         Alphanumeric series   28K  1.5M       2018.0  1.21M subscribers
# 1         Alphanumeric series   15K  393K          NaN  8.67M subscribers
# 2         Alphanumeric series    1K   52K       2023.0   475K subscribers
# 3         Alphanumeric series  9.7K  348K          NaN  1.14M subscribers
# 4         Alphanumeric series  1.9K   76K          NaN  1.73M subscribers
# ..                        ...   ...   ...          ...                ...
# 355  Points, lines and angles   18K  563K          NaN   203K subscribers
# 356  Points, lines and angles    22   973       2020.0  3.28K subscribers
# 357  Points, lines and angles   31K  735K       2021.0  2.23M subscribers
# 358  Points, lines and angles     6   462       2017.0  4.29K subscribers
# 359  Points, lines and angles    23   436          NaN  7.59K subscribers
#
#                                                  title duration  \
# 0    Series - Tricks & Shortcuts for Placement test...      NaN
# 1    Alphanumeric Series Reasoning Tricks and Conce...      NaN
# 2    ALPHA NUMERIC SERIES - A TO Z BEGINNERS SERIES...      NaN
# 3    NUMBER SERIES BEST SHORT TRICKS FOR ALL BANK, ...      NaN
# 4    Element Series - 10 Types - Reasoning Ability ...      NaN
# ..                                                 ...      ...
# 355                  ANGLE THEOREMS - Top 10 Must Know      NaN
# 356                      Geometry - 1 (Lines & Angles)      NaN
# 357  Geometry Trick | Lines and Angles | Maths Tric...      NaN
# 358  LINES AND ANGLES(Geometry) (Part 1) Angles, De...      NaN
# 359  Lines and Angles | GEOMETRY || CUET PG TISSNET...      NaN
#
#                                            description  \
# 0    Crack the logical reasoning section of Placeme...
# 1    Alphanumeric Series Reasoning Tricks and Conce...
# 2                                       Royale pass :
# 3                         #Onlineclasses_CL_9676578793
# 4                                     #feelfreetolearn
# ..                                                 ...
# 355  Here are the top 10 most important angle theor...
# 356  Geometry concept is very important in the lane...
# 357  Hello Friends\nThis is a awesome video for Geo...
# 358                           Follow  us on Twitter =
# 359  Lines and Angles | GEOMETRY || CUET PG TISSNET...
#
#                                  channel_name
# 0                                  CareerRide
# 1                                    Adda247
# 2                             Crack with Jack
# 3                              Chandan Logics
# 4                          Feel Free to Learn
# ..                                        ...
# 355                                JensenMath
# 356                      Aptitude World NATUS
# 357                           imran sir maths
# 358  Aptitude-Reasoning-Shortcuts-Tips-Tricks
# 359                              MATHOLOGICAL
#
# [360 rows x 10 columns]

# %%
google_rows = df2[df2['link'].astype(str).str.contains("google", na=False)]


google_rows
df2.drop(google_rows.index, inplace=True)
df2
# Out:
#                                                   link  \
# 0    https://www.youtube.com/watch?v=gXBuL_FyahE&t=...
# 1    https://www.youtube.com/watch?v=ka2fuIyrRZY&pp...
# 2    https://www.youtube.com/watch?v=co_6LHwUdqc&pp...
# 3    https://www.youtube.com/watch?v=exAPyTTZ2uU&pp...
# 4    https://www.youtube.com/watch?v=3cZFoiDcpTY&pp...
# ..                                                 ...
# 355  https://www.youtube.com/watch?v=Bq1QyT-HZrU&pp...
# 356  https://www.youtube.com/watch?v=CsyoFsx8PGg&pp...
# 357  https://www.youtube.com/watch?v=pvn5SzkcQ5c&pp...
# 358  https://www.youtube.com/watch?v=3FFI2Bm-obI&pp...
# 359  https://www.youtube.com/watch?v=VNEbhx4I6K8&pp...
#
#                         topic likes views  upload_year   subscriber_count  \
# 0         Alphanumeric series   28K  1.5M       2018.0  1.21M subscribers
# 1         Alphanumeric series   15K  393K          NaN  8.67M subscribers
# 2         Alphanumeric series    1K   52K       2023.0   475K subscribers
# 3         Alphanumeric series  9.7K  348K          NaN  1.14M subscribers
# 4         Alphanumeric series  1.9K   76K          NaN  1.73M subscribers
# ..                        ...   ...   ...          ...                ...
# 355  Points, lines and angles   18K  563K          NaN   203K subscribers
# 356  Points, lines and angles    22   973       2020.0  3.28K subscribers
# 357  Points, lines and angles   31K  735K       2021.0  2.23M subscribers
# 358  Points, lines and angles     6   462       2017.0  4.29K subscribers
# 359  Points, lines and angles    23   436          NaN  7.59K subscribers
#
#                                                  title duration  \
# 0    Series - Tricks & Shortcuts for Placement test...      NaN
# 1    Alphanumeric Series Reasoning Tricks and Conce...      NaN
# 2    ALPHA NUMERIC SERIES - A TO Z BEGINNERS SERIES...      NaN
# 3    NUMBER SERIES BEST SHORT TRICKS FOR ALL BANK, ...      NaN
# 4    Element Series - 10 Types - Reasoning Ability ...      NaN
# ..                                                 ...      ...
# 355                  ANGLE THEOREMS - Top 10 Must Know      NaN
# 356                      Geometry - 1 (Lines & Angles)      NaN
# 357  Geometry Trick | Lines and Angles | Maths Tric...      NaN
# 358  LINES AND ANGLES(Geometry) (Part 1) Angles, De...      NaN
# 359  Lines and Angles | GEOMETRY || CUET PG TISSNET...      NaN
#
#                                            description  \
# 0    Crack the logical reasoning section of Placeme...
# 1    Alphanumeric Series Reasoning Tricks and Conce...
# 2                                       Royale pass :
# 3                         #Onlineclasses_CL_9676578793
# 4                                     #feelfreetolearn
# ..                                                 ...
# 355  Here are the top 10 most important angle theor...
# 356  Geometry concept is very important in the lane...
# 357  Hello Friends\nThis is a awesome video for Geo...
# 358                           Follow  us on Twitter =
# 359  Lines and Angles | GEOMETRY || CUET PG TISSNET...
#
#                                  channel_name
# 0                                  CareerRide
# 1                                    Adda247
# 2                             Crack with Jack
# 3                              Chandan Logics
# 4                          Feel Free to Learn
# ..                                        ...
# 355                                JensenMath
# 356                      Aptitude World NATUS
# 357                           imran sir maths
# 358  Aptitude-Reasoning-Shortcuts-Tips-Tricks
# 359                              MATHOLOGICAL
#
# [347 rows x 10 columns]

# %%
df2 = df2.sort_values(by='topic')
df2 = df2.reset_index(drop=True)
df2
# Out:
#                                                   link  \
# 0    https://www.youtube.com/watch?v=ay9P_Pmpb_M&pp...
# 1    https://www.youtube.com/watch?v=tTomwopxKFE&pp...
# 2    https://www.youtube.com/watch?v=MY85lI287rk&pp...
# 3    https://www.youtube.com/watch?v=5dlkQH7duzc&pp...
# 4    https://www.youtube.com/watch?v=gA0EFrv9aL0&pp...
# ..                                                 ...
# 342  https://www.youtube.com/watch?v=8OOBo5C7dsc&t=...
# 343  https://www.youtube.com/watch?v=I-mmRzLdrxw&pp...
# 344  https://www.youtube.com/watch?v=KE7tQf9spPg&pp...
# 345  https://www.youtube.com/watch?v=yAMCsmAdWR8&pp...
# 346  https://www.youtube.com/watch?v=lr4PAj8E0Vs&pp...
#
#                         topic likes views  upload_year   subscriber_count  \
# 0                     Algebra   21K  675K       2021.0   129K subscribers
# 1                     Algebra   28K  967K          NaN   201K subscribers
# 2                     Algebra   727   93K       2017.0   677K subscribers
# 3                     Algebra  9.5K  267K       2022.0  97.9K subscribers
# 4    Alligations and mixtures   74K    2M       2020.0  20.2M subscribers
# ..                        ...   ...   ...          ...                ...
# 342            Work and Wages  6.8K  498K       2018.0  1.21M subscribers
# 343            Work and Wages   19K  1.2M       2018.0  1.73M subscribers
# 344            Work and Wages   54K  3.3M       2018.0  1.21M subscribers
# 345            Work and Wages     1    36       2020.0     29 subscribers
# 346            Work and Wages     1    39       2023.0     49 subscribers
#
#                                                  title duration  \
# 0    Grammar Hero's ASVAB Math Review: Back to the ...      NaN
# 1                       Algebra 1 Basics for Beginners      NaN
# 2    Smart Methods and Techniques to Solve Question...      NaN
# 3    IBEW Electrical Apprenticeship Math Aptitude T...      NaN
# 4    Alligations and Mixtures Tricks | Mixture and ...      NaN
# ..                                                 ...      ...
# 342  Work and Wages - Shortcuts & Tricks for Placem...      NaN
# 343         TIME AND WORK _ Work and Wages _ Lesson #4      NaN
# 344  Time and Work - Shortcuts & Tricks for Placeme...      NaN
# 345     Work and Wages #Aptitude #Work #Wage #Shortcut      NaN
# 346  Time and Work | Part 7 | Work and Wages | Apti...      NaN
#
#                                            description  \
# 0    In this video, I work out simple problems that...
# 1    Master the basics of Algebra 1 with our compre...
# 2    Subject: Quantitative Aptitude\nTopic: Algebra...
# 3    If you are applying for an apprenticeship thro...
# 4    Hi,\n\nIn this video, we are going to learn th...
# ..                                                 ...
# 342  Crack the quantitative aptitude section of Pla...
# 343                                   #FeelFreetoLearn
# 344  Crack the quantitative aptitude section of Pla...
# 345                                              #Work
# 346  Time and Work | Part 7 | Work and Wages | Apti...
#
#                          channel_name
# 0                        Grammar Hero
# 1                     UltimateAlgebra
# 2          TalentSprint Aptitude Prep
# 3    The Complete Guide to Everything
# 4                            Dear Sir
# ..                                ...
# 342                        CareerRide
# 343                Feel Free to Learn
# 344                        CareerRide
# 345                     Elite Careers
# 346                          Tutoralz
#
# [347 rows x 10 columns]

# %%
combined_df = pd.concat([df, df2], ignore_index=True)


combined_df
# Out:
#                                                   link  \
# 0    https://www.youtube.com/watch?v=3qSQGOzFUiA&pp...
# 1    https://www.youtube.com/watch?v=owanjQL07us&pp...
# 2    https://www.youtube.com/watch?v=Ik6M-hOkP8A&pp...
# 3    https://www.youtube.com/watch?v=ovX2siB6xLc&pp...
# 4    https://www.youtube.com/watch?v=u1OzWJh8Y6g&pp...
# ..                                                 ...
# 553  https://www.youtube.com/watch?v=8OOBo5C7dsc&t=...
# 554  https://www.youtube.com/watch?v=I-mmRzLdrxw&pp...
# 555  https://www.youtube.com/watch?v=KE7tQf9spPg&pp...
# 556  https://www.youtube.com/watch?v=yAMCsmAdWR8&pp...
# 557  https://www.youtube.com/watch?v=lr4PAj8E0Vs&pp...
#
#                         topic likes views  upload_year   subscriber_count  \
# 0                     Algebra    15   861       2020.0   677K subscribers
# 1                     Algebra  7.5K  359K          NaN   161K subscribers
# 2                     Algebra    74  5.2K       2020.0   677K subscribers
# 3    Alligations and mixtures   126  5.2K       2018.0   677K subscribers
# 4    Alligations and mixtures    44  6.5K       2017.0   677K subscribers
# ..                        ...   ...   ...          ...                ...
# 553            Work and Wages  6.8K  498K       2018.0  1.21M subscribers
# 554            Work and Wages   19K  1.2M       2018.0  1.73M subscribers
# 555            Work and Wages   54K  3.3M       2018.0  1.21M subscribers
# 556            Work and Wages     1    36       2020.0     29 subscribers
# 557            Work and Wages     1    39       2023.0     49 subscribers
#
#                                                  title duration  \
# 0    Algebra | Additional Example 27 and 28 | Quant...      NaN
# 1    NUMERICAL ABILITY REVIEWER | Math Random Problems      NaN
# 2    Algebra | Introduction to Algebra | Basic Exam...      NaN
# 3    Alligations and Mixtures | Additional Example ...      NaN
# 4    Alligations and Mixtures | Advanced Example - ...      NaN
# ..                                                 ...      ...
# 553  Work and Wages - Shortcuts & Tricks for Placem...      NaN
# 554         TIME AND WORK _ Work and Wages _ Lesson #4      NaN
# 555  Time and Work - Shortcuts & Tricks for Placeme...      NaN
# 556     Work and Wages #Aptitude #Work #Wage #Shortcut      NaN
# 557  Time and Work | Part 7 | Work and Wages | Apti...      NaN
#
#                                            description  \
# 0                                         Subscribe @
# 1    NUMERICAL ABILITY REVIEWER Math Random Problem...
# 2    In this TalentSprint sesion on Algebra, our te...
# 3                                         Subscribe @
# 4                                         Subscribe @
# ..                                                 ...
# 553  Crack the quantitative aptitude section of Pla...
# 554                                   #FeelFreetoLearn
# 555  Crack the quantitative aptitude section of Pla...
# 556                                              #Work
# 557  Time and Work | Part 7 | Work and Wages | Apti...
#
#                    channel_name
# 0    TalentSprint Aptitude Prep
# 1                   NoMo Studio
# 2    TalentSprint Aptitude Prep
# 3    TalentSprint Aptitude Prep
# 4    TalentSprint Aptitude Prep
# ..                          ...
# 553                  CareerRide
# 554          Feel Free to Learn
# 555                  CareerRide
# 556               Elite Careers
# 557                    Tutoralz
#
# [558 rows x 10 columns]

# %%
combined_df = combined_df.sort_values(by='topic')
combined_df = combined_df.reset_index(drop=True)
combined_df
# Out:
#                                                   link           topic likes  \
# 0    https://www.youtube.com/watch?v=3qSQGOzFUiA&pp...         Algebra    15
# 1    https://www.youtube.com/watch?v=MY85lI287rk&pp...         Algebra   727
# 2    https://www.youtube.com/watch?v=5dlkQH7duzc&pp...         Algebra  9.5K
# 3    https://www.youtube.com/watch?v=tTomwopxKFE&pp...         Algebra   28K
# 4    https://www.youtube.com/watch?v=ay9P_Pmpb_M&pp...         Algebra   21K
# ..                                                 ...             ...   ...
# 553  https://www.youtube.com/watch?v=5iYvg3_-VTw&pp...  Work and Wages     4
# 554  https://www.youtube.com/watch?v=Ajn288_rB-E&pp...  Work and Wages   44K
# 555  https://www.youtube.com/watch?v=GDNwQFKgsys&pp...  Work and Wages   39K
# 556  https://www.youtube.com/watch?v=yAMCsmAdWR8&pp...  Work and Wages     1
# 557  https://www.youtube.com/watch?v=lr4PAj8E0Vs&pp...  Work and Wages     1
#
#     views  upload_year   subscriber_count  \
# 0     861       2020.0   677K subscribers
# 1     93K       2017.0   677K subscribers
# 2    267K       2022.0  97.9K subscribers
# 3    967K          NaN   201K subscribers
# 4    675K       2021.0   129K subscribers
# ..    ...          ...                ...
# 553   225       2023.0    63K subscribers
# 554  943K          NaN  2.23M subscribers
# 555  2.5M       2018.0   520K subscribers
# 556    36       2020.0     29 subscribers
# 557    39       2023.0     49 subscribers
#
#                                                  title duration  \
# 0    Algebra | Additional Example 27 and 28 | Quant...      NaN
# 1    Smart Methods and Techniques to Solve Question...      NaN
# 2    IBEW Electrical Apprenticeship Math Aptitude T...      NaN
# 3                       Algebra 1 Basics for Beginners      NaN
# 4    Grammar Hero's ASVAB Math Review: Back to the ...      NaN
# ..                                                 ...      ...
# 553  Time and Work Wages Examples || Lesson 4.6 || ...      NaN
# 554  Time & Work Trick | Maths Tricks | imran sir m...      NaN
# 555  Time and Work Problems Shortcut & Tricks (Part...      NaN
# 556     Work and Wages #Aptitude #Work #Wage #Shortcut      NaN
# 557  Time and Work | Part 7 | Work and Wages | Apti...      NaN
#
#                                            description  \
# 0                                         Subscribe @
# 1    Subject: Quantitative Aptitude\nTopic: Algebra...
# 2    If you are applying for an apprenticeship thro...
# 3    Master the basics of Algebra 1 with our compre...
# 4    In this video, I work out simple problems that...
# ..                                                 ...
# 553  Time and Work Wages Examples\nIn this class, W...
# 554                                 Buy Link Amazon –
# 555  In this video I will teach you 1 special Trick...
# 556                                              #Work
# 557  Time and Work | Part 7 | Work and Wages | Apti...
#
#                          channel_name
# 0          TalentSprint Aptitude Prep
# 1          TalentSprint Aptitude Prep
# 2    The Complete Guide to Everything
# 3                     UltimateAlgebra
# 4                        Grammar Hero
# ..                                ...
# 553                   Learning Monkey
# 554                   imran sir maths
# 555            Smart Study for Career
# 556                     Elite Careers
# 557                          Tutoralz
#
# [558 rows x 10 columns]

# %%
combined_df.to_csv("final_video_details_logical.csv", index=False)
